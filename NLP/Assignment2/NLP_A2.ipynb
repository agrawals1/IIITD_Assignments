# %% [markdown]
# # Preprocessing

# %%
# import libraries

import pandas as pd
import numpy as np
import re
import warnings
warnings.filterwarnings('ignore')

# %%
# read dataset

df = pd.read_csv("A2_dataset.csv")
df.head()
# Out:
#    LABEL                 DATE_TIME  \
# 0      0  Fri Jun 05 14:26:50 2009
# 1      1  Thu May 14 10:13:55 2009
# 2      1  Fri Jun 05 21:02:20 2009
# 3      1  Sun Jun 14 22:25:52 2009
# 4      1  Sun May 31 00:42:12 2009
#
#                                                 TEXT
# 0                  About to get threaded and scared
# 1  @awaisnaseer I like Shezan Mangooo too!!! I ha...
# 2  worked on my car after work. showering then go...
# 3  @Marama Actually we start this afternoon!  I w...
# 4  @gfalcone601 Aww Gi.don't worry.we'll vote for...

# %%
df.shape
# Out:
# (4287, 3)

# %%
df.LABEL.value_counts()
# Out:
# 1    2287
# 0    2000
# Name: LABEL, dtype: int64

# %%
# install libraries
import nltk

# !pip install autocorrect
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting autocorrect
#   Downloading autocorrect-2.6.1.tar.gz (622 kB)
#      |████████████████████████████████| 622 kB 27.9 MB/s
# Building wheels for collected packages: autocorrect
#   Building wheel for autocorrect (setup.py) ... done
#   Created wheel for autocorrect: filename=autocorrect-2.6.1-py3-none-any.whl size=622382 sha256=0d260eb39768b8376cb8b515a926e6f41a7b938651c55fb50e82f256dcbfc32e
#   Stored in directory: /root/.cache/pip/wheels/54/d4/37/8244101ad50b0f7d9bffd93ce58ed7991ee1753b290923934b
# Successfully built autocorrect
# Installing collected packages: autocorrect
# Successfully installed autocorrect-2.6.1
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
# import libraries
from nltk.stem.snowball import stopwords
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
from autocorrect import Speller


# create dataframe df1 same columns given in orignal dataset
df1 = df.copy()


# create required columns and initialize with 0
df1['white_space_removed'] = 0
df1['tokenized_data'] = 0
df1['stopword_removed_data'] = 0
df1['punct_removed_data'] = 0
df1['url_removed_data'] = 0
df1['spelling_checked_data'] = 0
df1['lemmetized_data'] = 0



# create object for lemmetizer and spelling checking
lemmatizer = WordNetLemmatizer()
spell = Speller(lang='en')


# iterate over each row of dataset and preprocess data
for i in range(df1.shape[0]):

  # white space removel
  df1['white_space_removed'][i] = re.sub("\s+", " ", df1.TEXT[i])


  # tokenization
  lower = df1['white_space_removed'][i].lower()
  tokenized_data = word_tokenize(lower)
  df1['tokenized_data'][i] = tokenized_data
  # print(tokenized_data)


  # remove stopwords
  stop_words = "|".join(stopwords.words('english'))
  pattern = re.compile(r'\b(' + stop_words + r')\b\s*')
  stopword_removed_data = [pattern.sub("", text) for text in tokenized_data]
  stopword_removed_data = [x for x in stopword_removed_data if x]
  df1['stopword_removed_data'][i] = stopword_removed_data 
  # print(stopword_removed_data)


  # punctuation removel
  punct_removed_data = [x for x in stopword_removed_data if x.isalnum()]
  df1['punct_removed_data'][i] = punct_removed_data
  # print(punct_removed_data)
  

  # remove urls and html tags
  urls = re.findall("https?://[a-zA-Z0-9_\?=\@\/#=.~-]+", " ".join(punct_removed_data))
  url_removed_data = [x for x in punct_removed_data if x not in urls]
  df1['url_removed_data'][i] = url_removed_data
  # print(url_removed_data)  


  # spelling checking
  spelling_checked_data = [spell(x) for x in url_removed_data]
  df1['spelling_checked_data'][i] = spelling_checked_data
  # print(spelling_checked_data)


  # lemmetization
  lemmas = []
  for w in spelling_checked_data:
    lemmas.append(lemmatizer.lemmatize(w, wordnet.VERB))
  df1['lemmetized_data'][i] = lemmas

# %%
df1.head()
# Out:
#    LABEL                 DATE_TIME  \
# 0      0  Fri Jun 05 14:26:50 2009
# 1      1  Thu May 14 10:13:55 2009
# 2      1  Fri Jun 05 21:02:20 2009
# 3      1  Sun Jun 14 22:25:52 2009
# 4      1  Sun May 31 00:42:12 2009
#
#                                                 TEXT  \
# 0                  About to get threaded and scared
# 1  @awaisnaseer I like Shezan Mangooo too!!! I ha...
# 2  worked on my car after work. showering then go...
# 3  @Marama Actually we start this afternoon!  I w...
# 4  @gfalcone601 Aww Gi.don't worry.we'll vote for...
#
#                                  white_space_removed  \
# 0                  About to get threaded and scared
# 1  @awaisnaseer I like Shezan Mangooo too!!! I ha...
# 2  worked on my car after work. showering then go...
# 3  @Marama Actually we start this afternoon! I wi...
# 4  @gfalcone601 Aww Gi.don't worry.we'll vote for...
#
#                                       tokenized_data  \
# 0            [about, to, get, threaded, and, scared]
# 1  [@, awaisnaseer, i, like, shezan, mangooo, too...
# 2  [worked, on, my, car, after, work, ., showerin...
# 3  [@, marama, actually, we, start, this, afterno...
# 4  [@, gfalcone601, aww, gi.do, n't, worry.we, 'l...
#
#                                stopword_removed_data  \
# 0                            [get, threaded, scared]
# 1  [@, awaisnaseer, like, shezan, mangooo, !, !, ...
# 2  [worked, car, work, ., showering, going, bed, ...
# 3  [@, marama, actually, start, afternoon, !, try...
# 4  [@, gfalcone601, aww, gi., n', worry., ', vote...
#
#                                   punct_removed_data  \
# 0                            [get, threaded, scared]
# 1  [awaisnaseer, like, shezan, mangooo, one, yest...
# 2  [worked, car, work, showering, going, bed, soo...
# 3  [marama, actually, start, afternoon, try, some...
# 4          [gfalcone601, aww, vote, coz, love, much]
#
#                                     url_removed_data  \
# 0                            [get, threaded, scared]
# 1  [awaisnaseer, like, shezan, mangooo, one, yest...
# 2  [worked, car, work, showering, going, bed, soo...
# 3  [marama, actually, start, afternoon, try, some...
# 4          [gfalcone601, aww, vote, coz, love, much]
#
#                                spelling_checked_data  \
# 0                            [get, threaded, scared]
# 1  [awaisnaseer, like, sedan, mango, one, yesterday]
# 2  [worked, car, work, showing, going, bed, soooo...
# 3  [drama, actually, start, afternoon, try, somet...
# 4            [falcon601, www, vote, col, love, much]
#
#                                      lemmetized_data
# 0                                [get, thread, scar]
# 1  [awaisnaseer, like, sedan, mango, one, yesterday]
# 2  [work, car, work, show, go, bed, sooooooooooo,...
# 3  [drama, actually, start, afternoon, try, somet...
# 4            [falcon601, www, vote, col, love, much]

# %%
# add starting and end of sentance
df1['preprocessed_text'] = 0

for i in range(df1.shape[0]):
  df1['preprocessed_text'][i] = "<s> " + " ".join(df1['lemmetized_data'][i]) + " </s>"

# %%
df1.head()
# Out:
#    LABEL                 DATE_TIME  \
# 0      0  Fri Jun 05 14:26:50 2009
# 1      1  Thu May 14 10:13:55 2009
# 2      1  Fri Jun 05 21:02:20 2009
# 3      1  Sun Jun 14 22:25:52 2009
# 4      1  Sun May 31 00:42:12 2009
#
#                                                 TEXT  \
# 0                  About to get threaded and scared
# 1  @awaisnaseer I like Shezan Mangooo too!!! I ha...
# 2  worked on my car after work. showering then go...
# 3  @Marama Actually we start this afternoon!  I w...
# 4  @gfalcone601 Aww Gi.don't worry.we'll vote for...
#
#                                  white_space_removed  \
# 0                  About to get threaded and scared
# 1  @awaisnaseer I like Shezan Mangooo too!!! I ha...
# 2  worked on my car after work. showering then go...
# 3  @Marama Actually we start this afternoon! I wi...
# 4  @gfalcone601 Aww Gi.don't worry.we'll vote for...
#
#                                       tokenized_data  \
# 0            [about, to, get, threaded, and, scared]
# 1  [@, awaisnaseer, i, like, shezan, mangooo, too...
# 2  [worked, on, my, car, after, work, ., showerin...
# 3  [@, marama, actually, we, start, this, afterno...
# 4  [@, gfalcone601, aww, gi.do, n't, worry.we, 'l...
#
#                                stopword_removed_data  \
# 0                            [get, threaded, scared]
# 1  [@, awaisnaseer, like, shezan, mangooo, !, !, ...
# 2  [worked, car, work, ., showering, going, bed, ...
# 3  [@, marama, actually, start, afternoon, !, try...
# 4  [@, gfalcone601, aww, gi., n', worry., ', vote...
#
#                                   punct_removed_data  \
# 0                            [get, threaded, scared]
# 1  [awaisnaseer, like, shezan, mangooo, one, yest...
# 2  [worked, car, work, showering, going, bed, soo...
# 3  [marama, actually, start, afternoon, try, some...
# 4          [gfalcone601, aww, vote, coz, love, much]
#
#                                     url_removed_data  \
# 0                            [get, threaded, scared]
# 1  [awaisnaseer, like, shezan, mangooo, one, yest...
# 2  [worked, car, work, showering, going, bed, soo...
# 3  [marama, actually, start, afternoon, try, some...
# 4          [gfalcone601, aww, vote, coz, love, much]
#
#                                spelling_checked_data  \
# 0                            [get, threaded, scared]
# 1  [awaisnaseer, like, sedan, mango, one, yesterday]
# 2  [worked, car, work, showing, going, bed, soooo...
# 3  [drama, actually, start, afternoon, try, somet...
# 4            [falcon601, www, vote, col, love, much]
#
#                                      lemmetized_data  \
# 0                                [get, thread, scar]
# 1  [awaisnaseer, like, sedan, mango, one, yesterday]
# 2  [work, car, work, show, go, bed, sooooooooooo,...
# 3  [drama, actually, start, afternoon, try, somet...
# 4            [falcon601, www, vote, col, love, much]
#
#                                    preprocessed_text
# 0                           <s> get thread scar </s>
# 1  <s> awaisnaseer like sedan mango one yesterday...
# 2  <s> work car work show go bed sooooooooooo tir...
# 3  <s> drama actually start afternoon try somethi...
# 4          <s> falcon601 www vote col love much </s>

# %%
data = pd.concat([df, df1['preprocessed_text']], axis=1)
data.head()
# Out:
#    LABEL                 DATE_TIME  \
# 0      0  Fri Jun 05 14:26:50 2009
# 1      1  Thu May 14 10:13:55 2009
# 2      1  Fri Jun 05 21:02:20 2009
# 3      1  Sun Jun 14 22:25:52 2009
# 4      1  Sun May 31 00:42:12 2009
#
#                                                 TEXT  \
# 0                  About to get threaded and scared
# 1  @awaisnaseer I like Shezan Mangooo too!!! I ha...
# 2  worked on my car after work. showering then go...
# 3  @Marama Actually we start this afternoon!  I w...
# 4  @gfalcone601 Aww Gi.don't worry.we'll vote for...
#
#                                    preprocessed_text
# 0                           <s> get thread scar </s>
# 1  <s> awaisnaseer like sedan mango one yesterday...
# 2  <s> work car work show go bed sooooooooooo tir...
# 3  <s> drama actually start afternoon try somethi...
# 4          <s> falcon601 www vote col love much </s>

# %%
data.to_csv('preprocessed_data.csv', index=False)

# %%
data = pd.read_csv('preprocessed_data.csv')
data.head()
# Out:
#    LABEL                 DATE_TIME  \
# 0      0  Fri Jun 05 14:26:50 2009
# 1      1  Thu May 14 10:13:55 2009
# 2      1  Fri Jun 05 21:02:20 2009
# 3      1  Sun Jun 14 22:25:52 2009
# 4      1  Sun May 31 00:42:12 2009
#
#                                                 TEXT  \
# 0                  About to get threaded and scared
# 1  @awaisnaseer I like Shezan Mangooo too!!! I ha...
# 2  worked on my car after work. showering then go...
# 3  @Marama Actually we start this afternoon!  I w...
# 4  @gfalcone601 Aww Gi.don't worry.we'll vote for...
#
#                                    preprocessed_text
# 0                           <s> get thread scar </s>
# 1  <s> awaisnaseer like sedan mango one yesterday...
# 2  <s> work car work show go bed sooooooooooo tir...
# 3  <s> drama actually start afternoon try somethi...
# 4          <s> falcon601 www vote col love much </s>

# %%
type(data.preprocessed_text)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## find vocabulary set and unigram count

# %%
# find vocabulary
# find unigram count for each unique words

vocab = set()
unigram_count = {}

for text in data.preprocessed_text.to_list():
  if type(text) != 'str':
    text = str(text)
  x = text.split()
  for word in x:
    if word not in vocab:
      vocab.add(word)
    if word not in unigram_count:
      unigram_count[word] = 1
    else:
      unigram_count[word] += 1

vocab = list(vocab)
print(len(vocab))
print(unigram_count)
# Out:
# 7348
# {'<s>': 4287, 'get': 531, 'thread': 1, 'scar': 11, '</s>': 4287, 'awaisnaseer': 1, 'like': 202, 'sedan': 1, 'mango': 3, 'one': 122, 'yesterday': 20, 'work': 244, 'car': 19, 'show': 56, 'go': 479, 'bed': 59, 'sooooooooooo': 1, 'tire': 45, 'sparrow': 1, 'sign': 9, 'lt': 45, 'cowboy': 2, 'gt': 24, 'drama': 4, 'actually': 29, 'start': 52, 'afternoon': 18, 'try': 81, 'something': 52, 'slow': 8, 'process': 3, 'collect': 2, 'many': 16, 'vac': 2, 'falcon601': 2, 'www': 55, 'vote': 15, 'col': 1, 'love': 219, 'much': 101, 'mrstessyman': 1, 'ever': 31, 'good': 268, 'day': 213, 'knitpicks': 1, 'getmevideo': 1, 'sorry': 67, 'forte': 1, 'ask': 18, 'trade': 2, 'scale': 2, 'answer': 20, 'ready': 37, 'church': 17, 'sum': 5, 'watch': 130, 'afa': 3, 'whoop': 4, 'djokovic': 1, 'live': 46, 'settle': 7, 'dvr': 1, 'suppose': 10, 'early': 35, 'tomorrow': 114, 'last': 101, 'open': 20, 'home': 113, 'goodnight': 13, 'need': 127, 'shake': 5, 'gloomy': 4, 'feel': 155, 'maybe': 26, 'rain': 45, 'minecraft': 1, 'ride': 17, 'sarah': 4, 'still': 127, 'afraid': 6, 'anything': 28, 'fun': 59, 'tb78': 1, 'cheer': 7, 'follow': 47, 'sokendrakouture': 1, 'yea': 12, 'alone': 17, 'morning': 114, 'bless': 10, 'another': 41, 'share': 11, 'light': 8, 'others': 4, 'realdeal32': 1, 'yoginifoodie': 1, 'well': 90, 'thank': 178, 'want': 160, 'mileycyrus': 18, 'play': 59, 'own': 2, 'afeeee': 3, 'btw': 17, 'hot': 27, 'tub': 1, 'movie': 38, 'ice': 9, 'cream': 11, 'mt': 1, 'lil': 4, 'sis': 7, 'call': 54, 'night': 114, 'nothing': 37, 'time': 177, 'flyingbolt': 1, 'without': 19, 'lol': 174, 'help': 40, 'obsess': 1, 'hannah': 4, 'montana': 4, 'hate': 48, 'people': 41, 'move': 25, 'away': 37, 'http': 183, 'sad': 83, 'iranelection': 4, 'sctunstall': 1, 'wah': 5, 'glad': 28, 'cut': 5, 'run': 32, 'two': 19, 'west': 3, 'wing': 6, 'episodes': 3, 'digitallearnin': 1, 'ppell': 1, 'sentence': 1, 'describe': 2, 'see': 164, 'nz': 1, 'school': 57, 'develop': 1, 'current': 2, 'govt': 1, 'ihauntwizards': 1, 'amaze': 38, 'luke': 3, 'oh': 97, 'please': 44, 'music': 20, 'hear': 46, 'whole': 17, 'really': 149, 'buckhollywood': 1, 'cant': 50, 'uk': 3, 'tell': 44, 'x': 37, 'wont': 18, 'forget': 28, 'today': 166, 'soycamo': 1, 'right': 84, 'page': 21, 'write': 15, 'ruby': 1, 'cocoa': 1, 'okay': 18, 'permission': 1, 'give': 54, 'credit': 4, 'miss': 154, 'freshman': 1, 'year': 27, 'domkoenig': 1, 'nice': 66, 'pic': 16, 'shirt': 5, 'mykiaisosm': 1, 'om': 5, 'ur': 35, 'bad': 59, 'mean': 32, 'meet': 39, 'u': 136, '2nd': 4, 'grade': 5, 'even': 59, 'though': 64, 'hat': 8, 'stay': 26, 'cyberela': 1, 'quot': 204, 'classic': 3, 'bathroom': 1, 'sparkle': 2, 'since': 32, '7': 5, 'ta': 37, 'wrong': 16, 'next': 46, 'poor': 23, 'l': 6, 'sleepy': 8, '8am': 2, 'case': 12, 'spencerpratt': 1, 'cool': 40, 'eat': 57, 'chocolate': 9, 'bridge': 3, 'moz': 1, 'cancel': 5, 'kill': 21, 'game': 33, 'marginatasnaily': 1, 'yeah': 73, 'use': 51, 'load': 6, 'age': 8, 'tonight': 74, 'seem': 26, 'scare': 4, 'xxx': 8, 'finally': 26, 'back': 168, 'waste': 4, 'week': 59, 'webcam': 2, 'student': 1, 'phone': 47, 'tweet': 62, 'crave': 2, 'junk': 1, 'food': 25, 'bossmobb': 1, 'goodmorning': 4, 'n': 31, 'goodnite': 1, 'newerdeal': 1, 'perimeter': 1, 'nintendo': 1, 'ds': 3, 'think': 140, 'mention': 10, 'cat': 14, 'apps': 5, 'little': 46, 'hide': 6, 'worry': 14, 'effect': 4, 'stats': 1, 'thunder': 4, 'lightning': 3, 'careful': 3, 'georgetta': 1, '3': 60, 'rayon': 1, 'rule': 3, 'cikajang': 1, 'yum': 4, 'eagles89': 1, 'face': 15, 'bonnaroo': 3, 'stupid': 19, 'twitter': 106, 'keep': 47, 'capacity': 1, 'completely': 3, 'bore': 42, 'blah': 2, 'hug': 15, 'wan': 40, 'na': 105, 'wake': 46, 'goo': 4, 'dolls': 2, 'everyone': 36, 'grumpy': 2, 'guilt': 1, 'house': 30, 'include': 7, 'suck': 41, 'rewrite': 1, 'dave': 2, 'guy': 52, 'sup': 4, 'dr': 3, 'office': 16, 'hopefully': 24, 'find': 73, 'sick': 40, 'hard': 32, 'eye': 14, 'crush': 4, 'notice': 3, 'esp': 4, 'weekdays': 1, 'great': 87, 'sushi': 5, 'roll': 6, 'super': 17, 'cheap': 4, 'hope': 99, 'youre': 4, 'w ...

# %% [markdown]
# ## find bigram count

# %%
bigram_count = {}

for text in data.preprocessed_text.to_list():
  if type(text) != 'str':
    text = str(text)
  temp = text.split()
  for p in range(len(temp)-1):
    w1 = temp[p]
    w2 = temp[p+1]
    if (w1, w2) in bigram_count:
      bigram_count[(w1, w2)] += 1
    else:
      bigram_count[(w1, w2)] = 1

# print(bigram_count)
temp = list(bigram_count.items())[:5]
for i in temp:
  print(i[0], ":", i[1])
# Out:
# ('<s>', 'get') : 67
# ('get', 'thread') : 1
# ('thread', 'scar') : 1
# ('scar', '</s>') : 2
# ('<s>', 'awaisnaseer') : 1

# %% [markdown]
# ## find probability of bigram

# %%
p_bigram = {}

for k, v in bigram_count.items():
  p_bigram[(k)] = bigram_count[(k)] / unigram_count[k[0]]
  
# print(p_bigram)
temp = list(p_bigram.items())[:5]
for i in temp:
  print(i[0], ":", i[1])
# Out:
# ('<s>', 'get') : 0.01562864473991136
# ('get', 'thread') : 0.0018832391713747645
# ('thread', 'scar') : 1.0
# ('scar', '</s>') : 0.18181818181818182
# ('<s>', 'awaisnaseer') : 0.00023326335432703523

# %%
laplace_prob = {}
x = len(vocab)

for i in vocab:
  for j in vocab:
    if (i,j) in bigram_count:
      laplace_prob[(i,j)] = (bigram_count[(i,j)] + 1)/(unigram_count[i] + x) 
    else:
      laplace_prob[(i,j)] = 1/(unigram_count[i] + x)

temp = list(laplace_prob.items())[:5]
for i in temp:
  print(i[0], ":", i[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fd3bcd5767a4> in <module>
#       1 laplace_prob = {}
# ----> 2 x = len(vocab)
#       3
#       4 for i in vocab:
#       5   for j in vocab:
#
# NameError: name 'vocab' is not defined

# %% [markdown]
# ## Generate text

# %%
import random

# generate next word based on previous contenxt
def generate_next_word(prev_context):
    random_num = random.random()
    context_token_prob = {}
    
    # find probability of each bigram which contains previous context
    token_of_interest = [prev[1] for prev in bigram_count.keys() if prev[0] == prev_context]
    for token in token_of_interest:
        context_token_prob[token] = laplace_prob[(prev_context, token)]
    # return words with highest probability after the context
    total = 0
    for token in context_token_prob:
        total += context_token_prob[token]
        if (total > random_num):
            # print(token)
            return token
        


# generate sentance based on no. of words
def generate_sentence():
  current_context = '<s>' # current last word as context
  sentance = ['<s>'] # final sentance
  
  x = 1
  minimum = 7
  maximum = 25
  while x <= maximum:
    # generate next word
    generated_word = generate_next_word(current_context)
    sentance.append(generated_word)
    if generated_word == '</s>' and x <= minimum:
      sentance.pop(-1)
    elif generated_word == '</s>' and x > minimum:
      sentance.pop(-1)
      break
    else:
      current_context = generated_word
    x += 1
  sentance.append('</s>')
  return ' '.join(sentance)
    

generate_sentence()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2c59480505ac> in <module>
#      44
#      45
# ---> 46 generate_sentence()
#
# <ipython-input-1-2c59480505ac> in generate_sentence()
#      30   while x <= maximum:
#      31     # generate next word
# ---> 32     generated_word = generate_next_word(current_context)
#      33     sentance.append(generated_word)
#      34     if generated_word == '</s>' and x <= minimum:
#
# <ipython-input-1-2c59480505ac> in generate_next_word(prev_context)
#       7
#       8     # find probability of each bigram which contains previous context
# ----> 9     token_of_interest = [prev[1] for prev in bigram_count.keys() if prev[0] == prev_context]
#      10     for token in token_of_interest:
#      11         context_token_prob[token] = laplace_prob[(prev_context, token)]
#
# NameError: name 'bigram_count' is not defined

# %% [markdown]
# ## Laplace Smoothing

# %%
# laplace_prob = {}
# x = len(vocab)

# for i in vocab:
#   for j in vocab:
#     if (i,j) in bigram_count:
#       laplace_prob[(i,j)] = (bigram_count[(i,j)]+1)/(unigram_count[i] + x) 
#     else:
#       laplace_prob[(i,j)] = 1/(unigram_count[i] + x)

# %%
len(laplace_prob)

# %%
x**2
